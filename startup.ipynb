# %%
import pandas as pd
from statsbombpy import sb
from mplsoccer import Pitch

# %%
sb.competitions()[sb.competitions().country_name=='England']
# Out:
# C:\Users\OwenW\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id  ... match_available_360             match_available
# 25              37         90  ...                None  2023-02-25T14:52:09.326729
# 26              37         42  ...                None  2024-02-12T15:05:34.211400
# 27              37          4  ...                None  2024-06-12T07:41:45.347457
# 64               2         27  ...                None  2024-06-12T07:43:56.243851
# 65               2         44  ...                None  2024-03-08T14:49:13.195793
#
# [5 rows x 12 columns]

# %%
sb.matches(competition_id=2, season_id=27)
# Out:
# C:\Users\OwenW\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      match_id  match_date  ... shot_fidelity_version xy_fidelity_version
# 0     3754058  2016-01-02  ...                     2                   2
# 1     3754245  2015-10-17  ...                     2                   2
# 2     3754136  2015-12-19  ...                     2                   2
# 3     3754037  2016-04-30  ...                     2                   2
# 4     3754039  2016-02-13  ...                     2                   2
# ..        ...         ...  ...                   ...                 ...
# 375   3754020  2015-08-17  ...                     2                   2
# 376   3754267  2015-08-15  ...                     2                   2
# 377   3754141  2015-08-09  ...                     2                   2
# 378   3754128  2015-08-08  ...                     2                   2
# 379   3754078  2015-08-08  ...                     2                   2
#
# [380 rows x 22 columns]
